# %%
class Ability:
    def __init__(self, triggers, effects):
        pass

    def check_trigger():
        pass



    def use_ability

# %%
class Team_Ability(Ability):
    def __init__(self, triggers, effects, sources = None, targets = None, value1 = None, value2 = None, summons = None,
                 num_uses = None):
        pass

# %%
class Tiger_Ability(Team_Ability):
    pass

# %%
class Shop_Ability(Ability):
    def __init__(self, triggers, effects, num_uses = None)

# %%
class Trigger_State:
    pass

# %%
class Target:
    pass

# %%
class Effect:
    pass

# %%
class
